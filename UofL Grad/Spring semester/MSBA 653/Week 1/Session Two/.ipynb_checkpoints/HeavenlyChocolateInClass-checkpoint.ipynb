# %% [markdown]
# ### Exercise 2

# %% [markdown]
# Fit multiple linear regression using the same data as exercise 1 which is the Heavenly chocolates dataset also located in the python lab: linear regression. The goal is to predict amount spent. Provide important variables and business recommendations.

# %%
# separate data set into training and testing sets

from sklearn.model_selection import train_test_split

# Define predictors (X) and response (y)
X = pd.get_dummies(df.drop(columns=["Amount Spent"]), drop_first=True) 
Y = df["Amount Spent"]


# Train/test split (80/20) 
X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size=0.2, random_state=99
)

# %%
# Train Model 

from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression

# Build a pipeline which is your model
linreg_pipe = Pipeline([
    ("model", LinearRegression())
])

# Fit the model on the training set
linreg_pipe.fit(X_train, Y_train)
# Out:
# Pipeline(steps=[('model', LinearRegression())])

# %%
# Inspection of coefficeints

model = linreg_pipe.named_steps["model"]

coef = pd.Series(model.coef_, index=X.columns)
intercept = model.intercept_


display(coef.to_frame("coef"))
print("Intercept:", intercept)
# Out:
#                       coef
# Time              1.530206
# Pages Viewed      7.833863
# Day_Mon         -16.102870
# Day_Sat         -37.112667
# Day_Sun         -32.413894
# Day_Thu         -23.375413
# Day_Tue         -21.444106
# Day_Wed         -24.162013
# Browser_Firefox   0.621911
# Browser_Other     0.677778
# Intercept: 29.24874507725449

# %%
df = df.rename(columns={
    "Pages Viewed": "Pages_Viewed",
    "Amount Spent": "Amount_Spent"
})

# %%
import statsmodels.api as sm

# Convert booleans to integers
X_train = X_train.astype(float)
X_test = X_test.astype(float)

ols = sm.OLS(Y_train, X_train_const).fit()
print(ols.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           Amount Spent   R-squared:                       0.571
# Model:                            OLS   Adj. R-squared:                  0.423
# Method:                 Least Squares   F-statistic:                     3.857
# Date:                Tue, 13 Jan 2026   Prob (F-statistic):            0.00211
# Time:                        20:55:31   Log-Likelihood:                -171.81
# No. Observations:                  40   AIC:                             365.6
# Df Residuals:                      29   BIC:                             384.2
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const              29.6760     13.432      2.209      0.035       2.204      57.148
# ...

# %%
#Prediction
Y_predictions = linreg_pipe.predict(X_test)
print(Y_predictions)
# Out:
# [ 96.3641648   46.22673054 129.44343565  58.50801879 158.5530526
#   32.57808606  39.69254468  47.31797081  70.41591629 106.2082424 ]

# %%
errors = Y_predictions - Y_test
# print(errors)
mse = np.mean(errors ** 2) 

print(mse)
# Out:
# 244.78706960963427
